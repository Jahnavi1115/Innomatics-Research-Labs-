# %% [markdown]
# # 1. User Login Check

# %% [markdown]
# ## Problem Statement:
# Given a username and password, check whether login is successful.
# username = "admin"
# password = "1234"
#
# Requirements:
# Print "Login Successful" if both username and password match
# Otherwise print "Invalid Credentials"
#
# Real-World Application: Authentication systems

# %%
email = "gadipudijahnavi@gmail.com"
password = "pgrJ@nu23"

# %%
user_email = input("Enter your email: ")
user_password = input("Enter your password: ")

if user_email == email and user_password == password:
    print("Login Successful - Welcome to your Email Account")
else:
    print("Invalid Email or Password")
# Out:
# Enter your email:  gadipudijahnavi@gmail.com
# Enter your password:  pgrJ@nu23
# Login Successful - Welcome to your Email Account

# %% [markdown]
# # 2. Pass / Fail Analyzer

# %% [markdown]
# ## Problem Statement:
# Analyze student results.
# marks = [45, 78, 90, 33, 60]
#
# Requirements:
# A student passes if marks ≥ 50,
# Count the total number of pass students,
# Count the total number of fail students,
# Print the final result clearly
#
# Real-World Application: Academic evaluation systems.

# %%
marks = [45, 78, 90, 33, 60]

# %%
pass_count = 0
fail_count = 0

# %%
for mark in marks:
    if mark >= 50:
        pass_count = pass_count + 1
    else:
        fail_count = fail_count + 1

# %%
total_students = len(marks)

print("Total Pass Students =", pass_count)
print("Total Fail Students =", fail_count)
print("Final Result =", total_students)
# Out:
# Total Pass Students = 3
# Total Fail Students = 2
# Final Result = 5

# %% [markdown]
# # 3. Simple Data Cleaner

# %% [markdown]
# ## Problem Statement:
# Clean and standardize user names.
#
# names = [" Alice ", "bob", " CHARLIE "]
#
# Requirements:
# Remove extra spaces
# Convert all names to lowercase
# Print the cleaned list
#
# Real-World Application: Data preprocessing before analysis

# %%
names = [" Alice ", "bob", " CHARLIE "]

for i in range(len(names)):
    names[i] = names[i].strip().lower()

print("Cleaned Customer Names:", names)
# Out:
# Cleaned Customer Names: ['alice', 'bob', 'charlie']

# %% [markdown]
# # 4. Message Length Analyzer

# %% [markdown]
# ## Problem Statement:
# Analyze message sizes.
# messages = ["Hi", "Welcome to the platform", "OK"]
#
# Requirements:
# Print the length of each message
# Flag messages longer than 10 characters
#
# Real-World Application: Text filtering and validation systems

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

# %%
for msg in messages:
    length = len(msg)
    print("Message:", msg)
    print("Length:", length)
    
    if length > 10:
        print("Status: Message is too long")
    else:
        print("Status: Message length is acceptable")
    
    print("------------------")
# Out:
# Message: Hi
# Length: 2
# Status: Message length is acceptable
# ------------------
# Message: Welcome to the platform
# Length: 23
# Status: Message is too long
# ------------------
# Message: OK
# Length: 2
# Status: Message length is acceptable
# ------------------

# %% [markdown]
# # 5. Error Message Detector

# %% [markdown]
# ## Problem Statement:
# Detect error messages from system logs.
# logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# Requirements: Count the number of "ERROR" entries
# Print the total error count
#
# Real-World Application: Monitoring and log analysis systems

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = logs.count("ERROR")

print("Server Log Analysis")
print("Total ERROR Entries:", error_count)
# Out:
# Server Log Analysis
# Total ERROR Entries: 2
